# %%
import matplotlib
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
plt.style.use('ggplot')
from matplotlib.pyplot import figure
import os   
import random
import math
import seaborn as sns
import scipy.stats as stats
from sklearn import linear_model
from sklearn.metrics import mean_squared_error
from sklearn import preprocessing
from sklearn import tree
from sklearn.ensemble import RandomForestClassifier
from sklearn import metrics
from faker import Faker

# %matplotlib inline
matplotlib.rcParams['figure.figsize'] = (12,8)

# %%
movies = pd.read_csv('\\Users\\Andrea\\movies.csv')
movies.head(10)
# Out:
#                                              name rating      genre  year  \
# 0                                     The Shining      R      Drama  1980
# 1                                 The Blue Lagoon      R  Adventure  1980
# 2  Star Wars: Episode V - The Empire Strikes Back     PG     Action  1980
# 3                                       Airplane!     PG     Comedy  1980
# 4                                      Caddyshack      R     Comedy  1980
# 5                                 Friday the 13th      R     Horror  1980
# 6                              The Blues Brothers      R     Action  1980
# 7                                     Raging Bull      R  Biography  1980
# 8                                     Superman II     PG     Action  1980
# 9                                 The Long Riders      R  Biography  1980
#
#                             released  score      votes            director  \
# 0      June 13, 1980 (United States)    8.4   927000.0     Stanley Kubrick
# ...

# %%
movies.shape
# Out:
# (7668, 15)

# %%
movies.describe()
# Out:
#               year        score         votes        budget         gross  \
# count  7668.000000  7665.000000  7.665000e+03  5.497000e+03  7.479000e+03
# mean   2000.405451     6.390411  8.810850e+04  3.558988e+07  7.850054e+07
# std      11.153508     0.968842  1.633238e+05  4.145730e+07  1.657251e+08
# min    1980.000000     1.900000  7.000000e+00  3.000000e+03  3.090000e+02
# 25%    1991.000000     5.800000  9.100000e+03  1.000000e+07  4.532056e+06
# 50%    2000.000000     6.500000  3.300000e+04  2.050000e+07  2.020576e+07
# 75%    2010.000000     7.100000  9.300000e+04  4.500000e+07  7.601669e+07
# max    2020.000000     9.300000  2.400000e+06  3.560000e+08  2.847246e+09
#
#            runtime
# count  7664.000000
# mean    107.261613
# std      18.581247
# min      55.000000
# 25%      95.000000
# 50%     104.000000
# 75%     116.000000
# max     366.000000

# %%
movies.dtypes
# Out:
# name         object
# rating       object
# genre        object
# year          int64
# released     object
# score       float64
# votes       float64
# director     object
# writer       object
# star         object
# country      object
# budget      float64
# gross       float64
# company      object
# runtime     float64
# dtype: object

# %%
# Count the NaN values on each column

# %%
for col in movies.columns:
    null = movies[col].count()
    print(col,null)
# Out:
# name 7668
# rating 7591
# genre 7668
# year 7668
# released 7666
# score 7665
# votes 7665
# director 7668
# writer 7665
# star 7667
# country 7665
# budget 5497
# gross 7479
# company 7651
# runtime 7664

# %%
for col in movies.columns:
    null = movies[col].isnull().sum()
    print(col,null)
# Out:
# name 0
# rating 77
# genre 0
# year 0
# released 2
# score 3
# votes 3
# director 0
# writer 3
# star 1
# country 3
# budget 2171
# gross 189
# company 17
# runtime 4

# %%
for col in movies.columns:
    null = np.mean(movies[col].isnull())
    print('{} - {}%'.format(col,null))
# Out:
# name - 0.0%
# rating - 0.010041731872717789%
# genre - 0.0%
# year - 0.0%
# released - 0.0002608242044861763%
# score - 0.0003912363067292645%
# votes - 0.0003912363067292645%
# director - 0.0%
# writer - 0.0003912363067292645%
# star - 0.00013041210224308815%
# country - 0.0003912363067292645%
# budget - 0.2831246739697444%
# gross - 0.02464788732394366%
# company - 0.002217005738132499%
# runtime - 0.0005216484089723526%

# %%
# I could remove NaN values and replace them with the mean

# %%
movies.dropna(subset=[], inplace=True)

# %%
mean = movies[].mean()
mean_revenue = np.where(movies[].isnull(), 
                       mean,                       
                       movies[])  
movies[] = mean_revenue
movies.head()

# %%
# Sort values

# %%
movies.sort_values(by=['gross'], inplace=False, ascending=False)
# Out:
#                                             name rating   genre  year  \
# 5445                                      Avatar  PG-13  Action  2009
# 7445                           Avengers: Endgame  PG-13  Action  2019
# 3045                                     Titanic  PG-13   Drama  1997
# 6663  Star Wars: Episode VII - The Force Awakens  PG-13  Action  2015
# 7244                      Avengers: Infinity War  PG-13  Action  2018
# ...                                          ...    ...     ...   ...
# 7663                                More to Life    NaN   Drama  2020
# 7664                                 Dream Round    NaN  Comedy  2020
# 7665                               Saving Mbango    NaN   Drama  2020
# 7666                                It's Just Us    NaN   Drama  2020
# 7667                                   Tee em el    NaN  Horror  2020
#
#                                released  score      votes       director  \
# ...

# %%
# Display all rows

# %%
pd.set_option('display.max_rows', None)

# %%
# Show values of a column without duplicates

# %%
movies['genre'].drop_duplicates().sort_values(ascending=False)
# Out:
# 202     18
# 262     17
# 7600    16
# 59      15
# 156     14
# 1382    13
# 7613    12
# 162     11
# 5       10
# 474      9
# 23       8
# 40       7
# 0        6
# 14       5
# 3        4
# 7        3
# 71       2
# 1        1
# 2        0
# Name: genre, dtype: int8

# %%
# Drop duplicates

# %%
movies['genre'] = movies['genre'].drop_duplicates()

# %%
movies.head()
# Out:
#    name  rating  genre  year  released  score      votes  director  writer  \
# 0  6587       6      6  1980      1705    8.4   927000.0      2589    4014
# 1  5573       6      1  1980      1492    5.8    65000.0      2269    1632
# 2  5142       4      0  1980      1771    8.7  1200000.0      1111    2567
# 3   286       4      4  1980      1492    7.7   221000.0      1301    2000
# 4  1027       6      4  1980      1543    7.3   108000.0      1054     521
#
#    star  country      budget        gross  company  runtime
# 0  1047       54  19000000.0   46998772.0     2319    146.0
# 1   327       55   4500000.0   58853106.0      731    104.0
# 2  1745       55  18000000.0  538375067.0     1540    124.0
# 3  2246       55   3500000.0   83453539.0     1812     88.0
# 4   410       55   6000000.0   39846344.0     1777     98.0

# %%
# Scatter plot: budget vs gross

movies.plot(kind="scatter",     # Create a scatterplot
              x="budget",          # Put carat on the x axis
              y="gross",          # Put price on the y axis
              figsize=(15,15))

 # xlim=(0,10),
 # ylim=(0,1000)

plt.title('Movies budgets and gross earnings' )
plt.xlabel('Movies budgets')
plt.ylabel('Gross earnings')
# Out:
# Text(0, 0.5, 'Gross earnings')

# %%
# Different scatter plot: budget vs gross

plt.scatter(x=movies['budget'], y=movies['gross'])
plt.title('Movies budgets and gross earnings' )
plt.xlabel('Movies budgets')
plt.ylabel('Gross earnings')
# Out:
# Text(0, 0.5, 'Gross earnings')

# %%
# Linear regression

sns.regplot(x='budget', y='gross', data=movies, scatter_kws={'color':'orange'}, line_kws={'color':'black'})
# Out:
# <Axes: xlabel='budget', ylabel='gross'>

# %%
# Different methods to measure correlation

# %%
movies.corr(method='kendall')
# Out:
# C:\Users\Andrea\AppData\Local\Temp\ipykernel_30292\76517693.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   movies.corr(method='kendall')
#              year     score     votes    budget     gross   runtime
# year     1.000000  0.067652  0.331465  0.224120  0.200618  0.097184
# score    0.067652  1.000000  0.300115 -0.000566  0.086046  0.283611
# votes    0.331465  0.300115  1.000000  0.353702  0.548899  0.198240
# budget   0.224120 -0.000566  0.353702  1.000000  0.512637  0.235483
# gross    0.200618  0.086046  0.548899  0.512637  1.000000  0.168933
# runtime  0.097184  0.283611  0.198240  0.235483  0.168933  1.000000

# %%
movies.corr() #Pearson
# Out:
# C:\Users\Andrea\AppData\Local\Temp\ipykernel_30292\4197049095.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   movies.corr() #Pearson
#              year     score     votes    budget     gross   runtime
# year     1.000000  0.097995  0.222945  0.329321  0.257486  0.120811
# score    0.097995  1.000000  0.409182  0.076254  0.186258  0.399451
# votes    0.222945  0.409182  1.000000  0.442429  0.630757  0.309212
# budget   0.329321  0.076254  0.442429  1.000000  0.740395  0.320447
# gross    0.257486  0.186258  0.630757  0.740395  1.000000  0.245216
# runtime  0.120811  0.399451  0.309212  0.320447  0.245216  1.000000

# %%
movies.corr(method='spearman')
# Out:
# C:\Users\Andrea\AppData\Local\Temp\ipykernel_30292\3797099519.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   movies.corr(method='spearman')
#              year     score     votes    budget     gross   runtime
# year     1.000000  0.099045  0.469829  0.317336  0.293084  0.142977
# score    0.099045  1.000000  0.428138 -0.001403  0.126116  0.399857
# votes    0.469829  0.428138  1.000000  0.502466  0.742050  0.290159
# budget   0.317336 -0.001403  0.502466  1.000000  0.693670  0.336370
# gross    0.293084  0.126116  0.742050  0.693670  1.000000  0.246243
# runtime  0.142977  0.399857  0.290159  0.336370  0.246243  1.000000

# %%
#Correlation of the numeric columns

correlation_matrix = movies.corr()
sns.heatmap(correlation_matrix, annot=True)
plt.show()
# Out:
# C:\Users\Andrea\AppData\Local\Temp\ipykernel_27864\1960366443.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   correlation_matrix = movies.corr()

# %%
#Correlation of all columns

df_numerized = movies

for col_name in df_numerized.columns:
    if (df_numerized[col_name].dtype == 'object'):
        df_numerized[col_name] = df_numerized[col_name].astype('category')
        df_numerized[col_name] = df_numerized[col_name].cat.codes
        
df_numerized.head()
# Out:
#    name  rating  genre  year  released  score      votes  director  writer  \
# 0  6587       6      6  1980      1705    8.4   927000.0      2589    4014
# 1  5573       6      1  1980      1492    5.8    65000.0      2269    1632
# 2  5142       4      0  1980      1771    8.7  1200000.0      1111    2567
# 3   286       4      4  1980      1492    7.7   221000.0      1301    2000
# 4  1027       6      4  1980      1543    7.3   108000.0      1054     521
#
#    star  country      budget        gross  company  runtime
# 0  1047       54  19000000.0   46998772.0     2319    146.0
# 1   327       55   4500000.0   58853106.0      731    104.0
# 2  1745       55  18000000.0  538375067.0     1540    124.0
# 3  2246       55   3500000.0   83453539.0     1812     88.0
# 4   410       55   6000000.0   39846344.0     1777     98.0

# %%
df_numerized.corr()
# Out:
#               name    rating     genre      year  released     score  \
# name      1.000000 -0.008069  0.016355  0.011453 -0.011311  0.017097
# rating   -0.008069  1.000000  0.072423  0.008779  0.016613 -0.001314
# genre     0.016355  0.072423  1.000000 -0.081261  0.029822  0.027965
# year      0.011453  0.008779 -0.081261  1.000000 -0.000695  0.097995
# released -0.011311  0.016613  0.029822 -0.000695  1.000000  0.042788
# score     0.017097 -0.001314  0.027965  0.097995  0.042788  1.000000
# votes     0.013088  0.033225 -0.145307  0.222945  0.016097  0.409182
# director  0.009079  0.019483 -0.015258 -0.020795 -0.001478  0.009559
# writer    0.009081 -0.005921  0.006567 -0.008656 -0.002404  0.019416
# star      0.006472  0.013405 -0.005477 -0.027242  0.015777 -0.001609
# country  -0.010737  0.081244 -0.037615 -0.070938 -0.020427 -0.133348
# budget    0.023970 -0.176002 -0.356564  0.329321  0.014683  0.076254
# gross     0.005533 -0.107339 -0.235650  0.257486  0.001659  0.186258
# ...

# %%
correlation_matrix = df_numerized.corr()
sns.heatmap(correlation_matrix, annot=True)
plt.show()

# %%
correlation_matrix = df_numerized.corr()
corr_pairs = correlation_matrix.unstack()
corr_pairs
# Out:
# name     name        1.000000
#          rating     -0.008069
#          genre       0.016355
#          year        0.011453
#          released   -0.011311
#                        ...
# runtime  country    -0.078412
#          budget      0.320447
#          gross       0.245216
#          company     0.034402
#          runtime     1.000000
# Length: 225, dtype: float64

# %%
sorted_pairs = corr_pairs.sort_values(ascending=False)
sorted_pairs
# Out:
# name      name        1.000000
# rating    rating      1.000000
# company   company     1.000000
# gross     gross       1.000000
# budget    budget      1.000000
# country   country     1.000000
# star      star        1.000000
# writer    writer      1.000000
# votes     votes       1.000000
# score     score       1.000000
# released  released    1.000000
# year      year        1.000000
# genre     genre       1.000000
# director  director    1.000000
# runtime   runtime     1.000000
# gross     budget      0.740395
# budget    gross       0.740395
# votes     gross       0.630757
# gross     votes       0.630757
# votes     budget      0.442429
# budget    votes       0.442429
# score     votes       0.409182
# votes     score       0.409182
# score     runtime     0.399451
# runtime   score       0.399451
# year      budget      0.329321
# budget    year        0.329321
#           runtime     0.320447
# runtime   budget      0.320447
#           votes       0.309212
# ...

# %%
high_corr = sorted_pairs[(sorted_pairs > 0.5)]
high_corr
# Out:
# name      name        1.000000
# rating    rating      1.000000
# company   company     1.000000
# gross     gross       1.000000
# budget    budget      1.000000
# country   country     1.000000
# star      star        1.000000
# writer    writer      1.000000
# votes     votes       1.000000
# score     score       1.000000
# released  released    1.000000
# year      year        1.000000
# genre     genre       1.000000
# director  director    1.000000
# runtime   runtime     1.000000
# gross     budget      0.740395
# budget    gross       0.740395
# votes     gross       0.630757
# gross     votes       0.630757
# dtype: float64

# %%
# there's a high correlation between gross and budget and between votes and gross
